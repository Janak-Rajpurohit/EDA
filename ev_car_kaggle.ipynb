# %% [markdown]
# TASKS:
# * **Some basic tasks would include**
#
# * Which car has the fastest 0-100 acceleration?
# * Which has the highest efficiency?
# * Does a difference in power train effect the range, top speed, efficiency?
# * Which manufacturer has the most number of vehicles?
# * How does price relate to rapid charging?

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("ElectricCarData_Clean.csv")
df.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
#  no of brands in dataset
x=df["Brand"]
y=np.arange(1,104)
plt.figure(figsize=(20,7))
plt.title("No. of Brands")
plt.xlabel("Brands")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.bar(x,y)
# Out:
# <BarContainer object of 103 artists>

# %%
# %matplotlib inline

x=df["Brand"]
y=df["AccelSec"]

ax=plt.figure(figsize=(20,7))
plt.title("Brand and Acceleration")
plt.xlabel("Brand")
plt.ylabel("Acceleration")
plt.xticks(rotation=45)
plt.bar(x,y)
# Out:
# <BarContainer object of 103 artists>

# %%
# Q- Which car has the fastest 0-100 acceleration?
# A- RENAULT

# %%
#  top speed and Brands 

x=df["Brand"]
y=df["TopSpeed_KmH"]

plt.figure(figsize=(20,7))
plt.title("Top Speed of Brands")
plt.xlabel("Brand")
plt.ylabel("Top Speed")
plt.xticks(rotation=45)
plt.bar(x,y)
# Out:
# <BarContainer object of 103 artists>

# %%
#  tesla , posche ,lucid are the fastest cars and smart is the lowest on

# %%
#  range and brand 
x=df["Brand"]
y=df["Range_Km"]
plt.figure(figsize=(20,5))
plt.title("Range of Brands")
plt.xlabel("Brand")
plt.ylabel("Range")
plt.xticks(rotation=45)
plt.bar(x,y)
# Out:
# <BarContainer object of 103 artists>

# %%
# Tesla has the highest range and Lucid , Lightyear too
#  Smart and Honda has lowest range

# %%
#  efficiency and Brands
x=df["Brand"]
y=df["Efficiency_WhKm"]

plt.figure(figsize=(20,5))
plt.title("Efficiency of Brands")
plt.xlabel("Brand")
plt.ylabel("Efficiency")
plt.xticks(rotation=45)
plt.bar(x,y)
# Out:
# <BarContainer object of 103 artists>

# %%
# Tesla , Audi ,Mercedes  has high eff
# Lightyear has the lowest eff

# %%
# price  and Brand
x=df["Brand"]
y=df["PriceEuro"]

plt.figure(figsize=(20,5))
plt.title("Price of Brands")
plt.xlabel("Brand")
plt.ylabel("Price (euro)")
plt.xticks(rotation=45)
plt.bar(x,y)
# Out:
# <BarContainer object of 103 artists>

# %%
# Tesla , porsche and lightyear are expensive

# %%
# Types of plug type
x=df["Brand"]
y=df["PlugType"]

df["PlugType"].value_counts().plot.pie(figsize=(7,15),autopct='%.0f%%',explode=(.1,.1,.1,.1))
# df['PlugType'].value_counts().plot.pie(figsize=(8,15),autopct='%.0f%%',explode=(.1,.1,.1,.1))
plt.title('Plug Type')
# Out:
# Text(0.5, 1.0, 'Plug Type')

# %%
#  Modt of brands uses type 2 CCS and Type 1 is least used

# %%
df["BodyStyle"].unique()
t=tuple([0.05 for i in df["BodyStyle"].unique()])
print(t)
# Out:
# (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)

# %%
# body  style

df["BodyStyle"].value_counts().plot.pie(figsize=(8,15),autopct='%.0f%%',explode=t)
plt.title("Body Style")
# Out:
# Text(0.5, 1.0, 'Body Style')

# %%
# SUV and Hatchback are major body types and Station and MPV is the minor

# %%
#  Segment of Brands
df["Segment"].value_counts().plot.pie(figsize=(8,15),autopct='%.0f%%',explode=tuple([0.05 for i in df["Segment"].unique()]))
plt.title("Segments of Brands")
# Out:
# Text(0.5, 1.0, 'Segments of Brands')

# %%
# C and B are the major segments and S  is the minor one

# %%
# seats of  brands
df["Seats"].value_counts().plot.pie(figsize=(5,15),autopct='%.0f%%',explode=tuple([0.05 for i in df["Seats"].unique()]))
plt.title("Seats in Brands")
# Out:
# Text(0.5, 1.0, 'Seats in Brands')

# %%
#  most of the cars are 5 seaters

# %%
import seaborn as sb

plt.figure(figsize=(18,7))
#  if .corr() is not given it will error could not convert name into float
sb.heatmap(df.corr(),linewidths=1,annot=True)
# Out:
# C:\Users\Janak\AppData\Local\Temp\ipykernel_9420\231226215.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(df.corr(),linewidths=1,annot=True)
# <AxesSubplot: >

# %%
df.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
#  power  Train is converted into numbers
df1=pd.concat([df,pd.get_dummies(df["PowerTrain"])],axis=1)
df1.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro  AWD  FWD  RWD
# 0  Type 2 CCS      Sedan       D      5      55480    1    0    0
# ...

# %%
#  droping power train and rwd as not required
df1=df1.drop(["PowerTrain","RWD"],axis=1)

# %%
df1.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge    PlugType  \
# 0       450              161            940         Yes  Type 2 CCS
# 1       270              167            250         Yes  Type 2 CCS
# 2       400              181            620         Yes  Type 2 CCS
# 3       360              206            560         Yes  Type 2 CCS
# 4       170              168            190         Yes  Type 2 CCS
#
#    BodyStyle Segment  Seats  PriceEuro  AWD  FWD
# 0      Sedan       D      5      55480    1    0
# ...

# %%
# Does a difference in power train effect the range, top speed, efficiency?
x=df["PowerTrain"]
plt.title("Power Train and Range")
plt.xlabel("Power Train")
plt.ylabel("Range")
plt.bar(x,df["Range_Km"],width=0.25)
# Out:
# <BarContainer object of 103 artists>

# %% [markdown]
# AWD has highest Range

# %%
x=df["PowerTrain"]
plt.title("Power Train and Top Speed")
plt.xlabel("Power Train")
plt.ylabel("Top Speed")
plt.bar(x,df["TopSpeed_KmH"],width=0.25)
# Out:
# <BarContainer object of 103 artists>

# %% [markdown]
# AWD has highest Top speed

# %%
x=df["PowerTrain"]
plt.title("Power Train and Efficiency")
plt.xlabel("Power Train")
plt.ylabel("Efficiency")
plt.bar(x,df["Efficiency_WhKm"],width=0.25)
# Out:
# <BarContainer object of 103 artists>

# %% [markdown]
# Efficiency is kind  of same in all

# %%
#  How does price relate to rapid charging?
plt.figure(figsize=(30,7))
plt.xlabel("Price")
plt.ylabel("Rapid Charge")
plt.scatter(df["PriceEuro"],df["RapidCharge"])

# %%
#  most of car with price in range 30000 and 100000 has rapid charge  
#  their no direct connecton between them

# %%
#  ml model to predict price of car 
from sklearn.linear_model  import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import train_test_split

# %%
df1.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge    PlugType  \
# 0       450              161            940         Yes  Type 2 CCS
# 1       270              167            250         Yes  Type 2 CCS
# 2       400              181            620         Yes  Type 2 CCS
# 3       360              206            560         Yes  Type 2 CCS
# 4       170              168            190         Yes  Type 2 CCS
#
#    BodyStyle Segment  Seats  PriceEuro  AWD  FWD
# 0      Sedan       D      5      55480    1    0
# ...

# %%
x.sample(20)
# Out:
# 66    FWD
# 88    AWD
# 73    AWD
# 68    FWD
# 25    RWD
# 52    FWD
# 30    AWD
# 27    AWD
# 41    FWD
# 85    FWD
# 72    AWD
# 84    FWD
# 55    RWD
# 40    AWD
# 36    FWD
# 20    FWD
# 54    AWD
# 6     FWD
# 7     FWD
# 60    FWD
# Name: PowerTrain, dtype: object

# %%
df1["FastCharge_KmH"].describe()
# Out:
# count     103
# unique     51
# top       230
# freq        6
# Name: FastCharge_KmH, dtype: object

# %%
df1[df1.FastCharge_KmH=='-']
# Out:
#        Brand              Model  AccelSec  TopSpeed_KmH  Range_Km  \
# 57  Renault           Twingo ZE      12.6           135       130
# 68  Renault   Kangoo Maxi ZE 33      22.4           130       160
# 77    Smart         EQ forfour       12.7           130        95
# 82    Smart     EQ fortwo coupe      11.6           130       100
# 91    Smart    EQ fortwo cabrio      11.9           130        95
#
#     Efficiency_WhKm FastCharge_KmH RapidCharge PlugType  BodyStyle Segment  \
# 57              164              -          No   Type 2  Hatchback       A
# 68              194              -          No   Type 2        SPV       N
# 77              176              -          No   Type 2  Hatchback       A
# 82              167              -          No   Type 2  Hatchback       A
# 91              176              -          No   Type 2     Cabrio       A
#
#     Seats  PriceEuro  AWD  FWD
# 57      4      24790    0    0
# 68      5      38000    0    1
# ...

# %%
# removing '-' in fast charge col
df1.drop([57,68,77,82,91],inplace=True)

# %%
df1.sample(30)
# Out:
#            Brand                           Model  AccelSec  TopSpeed_KmH  \
# 36        Lexus                          UX 300e       7.5           160
# 3           BMW                             iX3        6.8           180
# 37        CUPRA                         el-Born        6.5           160
# 44         SEAT                    Mii Electric       12.3           130
# 58      Citroen                            e-C4        9.7           150
# 27        Volvo             XC40 P8 AWD Recharge       4.9           180
# 47      Porsche                        Taycan 4S       4.0           250
# 78         Ford            Mustang Mach-E SR AWD       6.0           180
# 97        Byton                M-Byte 72 kWh 2WD       7.5           190
# 84     Mercedes                     EQV 300 Long      10.0           140
# 50         Audi                e-tron 55 quattro       5.7           200
# 1    Volkswagen                        ID.3 Pure      10.0           160
# ...

# %%
y=df1["PriceEuro"]
x=df1.drop(["Brand","Model","PlugType","BodyStyle","Segment","RapidCharge","PriceEuro"],axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
len(x_train),len(x_test)
# Out:
# (73, 25)

# %%
lr=LogisticRegression().fit(x_train,y_train)
rfc=RandomForestClassifier().fit(x_train,y_train)
dtc=DecisionTreeClassifier().fit(x_train,y_train)
# Out:
# C:\Users\Janak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(lr.score(x_test,y_test))
print(rfc.score(x_test,y_test))
print(dtc.score(x_test,y_test))
# Out:
# 0.04
# 0.04
# 0.04

# %%
y_pred=rfc.predict(x)
y_pred1=dtc.predict(x)
y_pred2=lr.predict(x)

# %%
from sklearn.metrics import accuracy_score
print("RFC",accuracy_score(y,y_pred))
print("DTC",accuracy_score(y,y_pred1))
print("LR",accuracy_score(y,y_pred2))
# Out:
# RFC 0.7244897959183674
# DTC 0.7244897959183674
# LR 0.45918367346938777

# %%
y_p=rfc.predict(x_test)
y_p1=dtc.predict(x_test)
y_p2=lr.predict(x_test)

print("RFC",accuracy_score(y_p,y_test))
print("DTC",accuracy_score(y_p1,y_test))
print("LR",accuracy_score(y_p2,y_test))
# Out:
# RFC 0.04
# DTC 0.04
# LR 0.04

# %%
from sklearn.metrics import r2_score
print("RFC",r2_score(y,y_pred ))
print("DTC",r2_score(y,y_pred1 ))
print("LR",r2_score(y,y_pred2 ))
# Out:
# RFC 0.967739967994665
# DTC 0.8715241822129266
# LR 0.7527914294502919

# %%
#  price and rapid charge model
x1=df1[["PriceEuro"]]
df1["RapidCharge"]=df1["RapidCharge"].apply(lambda x: 1 if x =="Yes" else 0)
y1=df1[["RapidCharge"]]

# %%
y1
# Out:
#      RapidCharge
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ..           ...
# 98             1
# 99             1
# 100            1
# 101            1
# 102            1
#
# [98 rows x 1 columns]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x1,y1,test_size=0.25)
len(X_train),len(X_test)
# Out:
# (73, 25)

# %%
from sklearn.linear_model import  LinearRegression

# %%
lin=LinearRegression().fit(X_train,Y_train)

# %%
lin.score(X_test,Y_test)
# Out:
# 1.0

# %%
y_predicted=lin.predict(x1)

# %%
accuracy_score(y1,y_predicted)
# Out:
# 1.0
